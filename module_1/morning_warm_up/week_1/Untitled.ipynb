# %%
nums = [2, 7, 11, 15]

# %%
def target(number):
# Out:
#     # --------------------------------------------------------------------
# 0                              # USE OF NOAA ESRL DATA
# 1                                                   #
# 2    # These data are made freely available to the ...
# 3    # scientific community in the belief that thei...
# 4    # will lead to greater understanding and new s...
# 5    # The availability of these data does not cons...
# 6    # of the data.  NOAA relies on the ethics and ...
# 7    # ensure that ESRL receives fair credit for th...
# 8    # are obtained for potential use in a publicat...
# 9    # ESRL should be informed at the outset of the...
# 10   # If the ESRL data are essential to the work, ...
# 11   # result or conclusion depends on the ESRL dat...
# 12   # may be appropriate.  This should be discusse...
# 13   # the work.  Manuscripts using the ESRL data s...
# 14   # for review before they are submitted for pub...
# 15   # ensure that the quality and limitations of t...
# ...
